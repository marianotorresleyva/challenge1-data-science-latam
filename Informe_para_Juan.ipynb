# %% [markdown]
# # Informe de Resultados
# Analisis de la recopilación de datos, y conclusiones.
#
# En la presente

# %% [markdown]
# presentacion Proposito o Intencion, metodología (tecnicas de recopilacion, evidencias), Descripción (Detalle certero), análisis , conclusiones, recomendaciones
